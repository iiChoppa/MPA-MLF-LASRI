# %% [markdown]
# # MPA-MLF, Lab 5 - Feedforward Neural Networks

# %% [markdown]
# These exercises are focused on dealing with neural networks. It is strongly recommended to use google collab for these pc labs. Why? Google collab offers a free GPU capacity to train machine learning models. Training NN on GPU can drastically speed up the training process. You can turn on the GPU accelerator in: Runtime -> Change runtime type -> GPU,

# %% [markdown]
# ## The basic terminology

# %% [markdown]
# ### Neural Networks

# %% [markdown]
# Think of a neural network as a complex web of neurons (or nodes) that are interconnected to process information, similar to how the human brain works. Each neuron in this network can receive inputs, process them, and pass on the output to other neurons. The goal of a neural network is to transform the inputs (e.g., images, texts, numbers) into a desired output (e.g., identifying what's in an image, translating text, etc.).

# %% [markdown]
# ![title](img/network.png)

# %% [markdown]
# ### Layers

# %% [markdown]
# A neural network is made up of layers: the input layer (where the data enters the network), one or more hidden layers (where most of the processing happens), and the output layer (where the final prediction is made). You can think of each layer as a filter that increasingly refines the information as it passes through the network. In our case, we will discuss feedforward, fully-connected neural networks. Fully connected means that every neuron in layer *n* is connected by a weighted connection with all neurons in the layers *n+1*. Feedforward means that data are passed in one direction only, there are no reccurent connections (feedback loops) exist.

# %% [markdown]
# ![title](img/Neural_network.png)

# %% [markdown]
# ### Neuron

# %% [markdown]
# A neuron, or node, is the basic unit of a neural network. It receives input, applies a weight (significance) to that input, adds a bias (a constant value to ensure the neuron activates correctly), and then uses an activation function to determine whether and how strongly to pass its signal to the next layer. Each neuron contributes to the network's ability to make accurate predictions or decisions.|

# %% [markdown]
# ![title](img/neuron.png)

# %% [markdown]
# ### Neuron in the input layer

# %% [markdown]
# In the input layer the input neurons are composed of identity only, that means everying that comes to the input comes directly to the output

# %% [markdown]
# ### Training

# %% [markdown]
# Training a neural network involves feeding it with data for which the correct output is known, allowing the network to adjust its weights and biases to minimize the difference between its predictions and the actual truths. This process is repeated numerous times with many data examples.

# %% [markdown]
# ### Loss Function

# %% [markdown]
# A loss function measures how well the neural network is performing, meaning how close or far its predictions are from the actual values. The goal of training is to minimize this loss, or error, making the network's predictions as accurate as possible.

# %% [markdown]
# ## Exercise 1 - XOR problem

# %% [markdown]
# During the last lecture, we saw that the single perceptron model with a step function could be used only for solving linearly-separable classification problems. Because of that, a single perceptron can not be trained to be able to behave like an XOR gate. To approximate the XOR gate using a neural network, we need to use the following structure:

# %% [markdown]
# ![nn.png](data:image/png;base64,...)

# %% [markdown]
# The above structure contains three layers: two neurons in the input layer (blue), two in the hidden layer and one in the output layer (yellow). The input layer represents the identity functions (the outputs are equal to the inputs)

# %% [markdown]
# We will use *Keras* API to build and train our neural network. Keras is an open-source neural network library written in Python. It is designed to enable fast experimentation with deep neural networks and provides a high-level API for building and training neural networks.

# %% [markdown]
# ### 0. First import libraries

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 1. prepare data

# %% [markdown]
# In this part, the task would be to prepade our dataset, basically it is the logic table for *XOR* function

# %%
X = [[0, 0], [0, 1], [1, 0], [1, 1]]
y = [0, 1, 1, 0]

# %% [markdown]
# ### 2. Creating the model

# %% [markdown]
# To create a model of NN that is in the picture above, run the following cell

# %%
model = Sequential()
model.add(InputLayer(shape=(2,))) # Corrected: used 'shape' and a tuple (2,)
model.add(Dense(2, activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# **Sequential** is a model type used in Keras for building feedforward neural networks. It is called "sequential" because the layers are stacked sequentially on top of each other, and the output of one layer is passed as input to the next layer.
#
# To create a sequential model, instantiate a Sequential object and then add layers to it using the **add()** method. There are many layers that Keras offers. We will use *Dense layer*
#
# **Dense layer** represents a fully connected layer, which means that every neuron in the layer is connected to every neuron in the previous layer. In each layer, we will specify an activation function and the number of neurons that layer contains. The input layer is not defined as a dense layer, but instead of that, we will specify the *input_dim* parameter in the layer that follows the input layer. *input_dim* parameter specifies the number of neurons in the input layer

# %% [markdown]
# ### 3. Compile the model

# %% [markdown]
# To compile yor model run:

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %% [markdown]
# **keras.complile()** is used to configure the learning process before training the model.
# We need to specify 3 parameters:
# - *loss*, *optimizer* and *metrics*
#
# - as our loss function (error function/objective function), we will choose *binary_crossentropy* - loss function often used for binary classification
#
# - *optimizer* is optimization algorithm used for optimizing weights in our training process, we will choose *stochastic gradient descent*
#
# - *metrics* is metric user for model evaluation

# %% [markdown]
# ### 4. Model training

# %% [markdown]
# In the lecture, we talked about training the Multi-layer perceptron. The training process consists of the following steps:
#
# 1. Weight initialization
# 2. Forward Propagation
# 3. Compute Loss
# 4. Backpropagation
# 5. Update Weights
# 6. Repeat 2->6 until maximum epochs are reached
#
# When training a machine learning model, the training data is usually divided into batches (parts), and the model updates its weights after processing each batch. The batch size determines how many training examples are included in each batch.
#
# For example, we have 10,000 training examples and a batch size of 100. In this case, the training data would be divided into 100 batches of 100 examples each. During training, the model would process each batch, calculate the loss or error, and update its weights based on the average of the errors in that batch. In other words, if we batch equal to 1. we will update the weights 10 000 times. If we have batch size == 100, we will update the weights only 100 times

# %% [markdown]
# To train your model, run the following line of the code:

# %%
history = model.fit(np.array(X), np.array(y), epochs=2000, batch_size=1, verbose=0)

# %% [markdown]
# the method **.fit()**, is used to train the model. We can see that it takes several input parameters:
#  - *X* - input data
#  - *y* - label for the input data
#  - *epochs* number of training epochs (iterations)
#  - *batch_size* - number of samples in each batch
#  - *verbose* - set verbose parameter to see the progress of loss and metrics during the training epochs
#
# These are not the only parameters the .fit() method can take. Check official documentation: https://keras.io/api/models/model_training_apis/
#
# We will set the output of our .fit() function to variable *history*, where the loss and other metrics defined above in the .compile() function during the training are saved.

# %%
plt.figure()
plt.plot(history.history['loss'])
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
plt.figure()
plt.plot(history.history['accuracy'])
plt.title('Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# ### 5. Model evaluation

# %% [markdown]
# Out training process is finished. To evaluate the performance of our model on test data, tun the following cell of the code:

# %%
loss, accuracy = model.evaluate(np.array(X), np.array(y), verbose=0)
print('Accuracy: {:.2f}'.format(accuracy*100))
# Out:
# Accuracy: 75.00

# %% [markdown]
# ### 6. Model predictions

# %%
for id_x, data_sample in enumerate(X):
  prediction = model.predict(np.array([data_sample]))
  print(f"Data sample is {data_sample}, prediction from model {prediction}, ground_truth {y[id_x]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# Data sample is [0, 0], prediction from model [[0.10777195]], ground_truth 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Data sample is [0, 1], prediction from model [[0.78927433]], ground_truth 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Data sample is [1, 0], prediction from model [[0.52577955]], ground_truth 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Data sample is [1, 1], prediction from model [[0.58356225]], ground_truth 0

# %% [markdown]
# ### 7. Display loss function during the training process and acuracy

# %%
plt.figure()
plt.plot(history.history['loss'])
plt.xlabel('n epochs')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %% [markdown]
# ### TASK:
#
# In this part of the exercise, the task would be to play around with the code above to see the influence of hyperparameters.
#
# As we know from the lecture, neural networks contain two types of parameters:
#   1. **Learnable parameters** - *weights* and *biases*. these parameters are adjusted in the training process.
#   2. **Non-learnable parameters (hyperparameters)** - learning_rate, number_of_neurons, number_of_layers, number_of_epochs, type of activation functions in the neurons.., basically any user-defined setting is considered to be hyperparameter
#
#
# Change the following parameters:
# - number of epochs
# - learning_rate
# - activation functions in layers,
# - batch_size,
# - verbose,
# - number of neurons in the hidden layer
#
# Moreover, see the influence on the training process and results.
#
# **Note: Every time we change some hyper-parameters, do not forget to compile the model, to initialize the learnable parameters again**

# %% [markdown]
# ## Exercise 2 - Congressional Voting Data
#
# In the attached dataset, results from congressional voting can be found. Your task is to train a model that can recognize that the politician is *republican* or *democrat* based on voting results. We would follow the general machine learning steps that were described in the lecture.

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Loading dataset

# %% [markdown]
# **First mount your google drive to google colab file.**

# %%
path_to_dataset = 'voting_complete.csv' # Corrected PATH
pd_dataset = pd.read_csv(path_to_dataset)

# %% [markdown]
# Let's list the contents of the directory `drive/MyDrive/MPA-MLF/EX_5/` to verify the presence and exact name of `voting_complete.csv`.

# %%
import os

# Define the directory where the file is expected
directory_path = 'drive/MyDrive/MPA-MLF/EX_5/'

# Check if the directory exists
if os.path.exists(directory_path):
    print(f"Contents of '{directory_path}':")
    for item in os.listdir(directory_path):
        print(item)
else:
    print(f"Directory '{directory_path}' does not exist. Please check your Google Drive path.")
# Out:
# Directory 'drive/MyDrive/MPA-MLF/EX_5/' does not exist. Please check your Google Drive path.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pd_dataset
# Out:
#      Unnamed: 0  Class Name handicapped-infants water-project-cost-sharing  \
# 0             0  republican                   n                          y
# 1             1  republican                   n                          y
# 2             2    democrat                   ?                          y
# 3             3    democrat                   n                          y
# 4             4    democrat                   y                          y
# ..          ...         ...                 ...                        ...
# 430         430  republican                   n                          n
# 431         431    democrat                   n                          n
# 432         432  republican                   n                          ?
# 433         433  republican                   n                          n
# 434         434  republican                   n                          y
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                   n                    y               y
# 1                                   n                    y               y
# 2                                   y                    ?               y
# 3                                   y                    n               ?
# 4                                   y                    n               y
# ..                                ...                  ...             ...
# 430                                 y                    y               y
# 431                                 y                    n               n
# 432                                 n                    y               y
# 433                                 n                    y               y
# 434                                 n                    y               y
#
#     religious-groups-in-schools anti-satellite-test-ban  \
# 0                             y                       n
# 1                             y                       n
# 2                             y                       n
# 3                             y                       n
# 4                             y                       n
# ..                          ...                     ...
# 430                           y                       n
# 431                           n                       y
# 432                           y                       n
# 433                           y                       ?
# 434                           y                       n
#
#     aid-to-nicaraguan-contras mx-missile immigration  \
# 0                           n          n           y
# 1                           n          n           n
# 2                           n          n           n
# 3                           n          n           n
# 4                           n          n           n
# ..                        ...        ...         ...
# 430                         n          y           y
# 431                         y          y           y
# 432                         n          n           n
# 433                         ?          ?           ?
# 434                         n          n           y
#
#     synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                              ?                  y                      y
# 1                              n                  y                      y
# 2                              y                  n                      y
# 3                              y                  n                      y
# 4                              y                  ?                      y
# ..                           ...                ...                    ...
# 430                            n                  y                      y
# 431                            n                  n                      n
# 432                            y                  y                      y
# 433                            n                  y                      y
# 434                            n                  y                      y
#
#     crime duty-free-exports export-administration-act-south-africa
# 0       y                 n                                      y
# 1       y                 n                                      ?
# 2       y                 n                                      n
# 3       n                 n                                      y
# 4       y                 y                                      y
# ..    ...               ...                                    ...
# 430     y                 n                                      y
# 431     n                 n                                      y
# 432     y                 n                                      y
# 433     y                 n                                      y
# 434     y                 ?                                      n
#
# [435 rows x 18 columns]

# %% [markdown]
# ### 2. Train/Test Split

# %% [markdown]
# Fistlty we need to split our dataset into train and test. We will use 80% of dataset as our trainset and 20% od dataset as our testset. You can use functions included in *keras*, *scikit-learn*, or you can write your own:

# %%
# define a function for train and test split

def train_test_split(pd_data: pd.DataFrame, test_ratio: float = 0.2, random_state: int = 42) -> tuple:
    pd_dataset = pd_data.copy()
    pd_dataset = pd_dataset[pd_dataset.columns[1:]]
    index = np.arange(len(pd_dataset))
    np.random.seed(random_state) # Set the random seed for reproducibility
    index = np.random.permutation(index)
    train_ammount = int(len(index)*(1 - test_ratio))
    train_ids = index[:train_ammount]
    test_ids = index[train_ammount:]

    train_dataset = pd_dataset[pd_dataset.index.isin(train_ids)].reset_index()
    test_dataset = pd_dataset[pd_dataset.index.isin(test_ids)].reset_index()

    train_dataset = train_dataset[train_dataset.columns[1:]]
    test_dataset = test_dataset[test_dataset.columns[1:]]

    return train_dataset[train_dataset.columns[1:]], train_dataset[train_dataset.columns[0]], test_dataset[test_dataset.columns[1:]], test_dataset[test_dataset.columns[0]]

# %%
x_train, y_train, x_test, y_test = train_test_split(pd_dataset)

# %% [markdown]
# ### 3. Data examination

# %% [markdown]
# The task would be to examine the dataset. Check:
#
# 1. Is it a classification of regression task?
# 2. How many data samples do we have?
# 3. How many features do we have?
# 4. What data types do we have in our dataset?
# 5. Are there any missing values?
# 6. How many labels do we have?

# %%
x_train
# Out:
#     handicapped-infants water-project-cost-sharing  \
# 0                     n                          y
# 1                     ?                          y
# 2                     n                          y
# 3                     y                          y
# 4                     n                          y
# ..                  ...                        ...
# 343                   n                          n
# 344                   y                          n
# 345                   n                          n
# 346                   n                          n
# 347                   n                          n
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                   n                    y               y
# 1                                   y                    ?               y
# 2                                   y                    n               ?
# 3                                   y                    n               y
# 4                                   y                    n               y
# ..                                ...                  ...             ...
# 343                                 n                    y               y
# 344                                 y                    n               ?
# 345                                 y                    y               y
# 346                                 y                    n               n
# 347                                 n                    y               y
#
#     religious-groups-in-schools anti-satellite-test-ban  \
# 0                             y                       n
# 1                             y                       n
# 2                             y                       n
# 3                             y                       n
# 4                             y                       n
# ..                          ...                     ...
# 343                           y                       y
# 344                           n                       y
# 345                           y                       n
# 346                           n                       y
# 347                           y                       ?
#
#     aid-to-nicaraguan-contras mx-missile immigration  \
# 0                           n          n           y
# 1                           n          n           n
# 2                           n          n           n
# 3                           n          n           n
# 4                           n          n           n
# ..                        ...        ...         ...
# 343                         y          n           y
# 344                         y          y           y
# 345                         n          y           y
# 346                         y          y           y
# 347                         ?          ?           ?
#
#     synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                              ?                  y                      y
# 1                              y                  n                      y
# 2                              y                  n                      y
# 3                              y                  ?                      y
# 4                              n                  n                      y
# ..                           ...                ...                    ...
# 343                            n                  y                      y
# 344                            n                  y                      n
# 345                            n                  y                      y
# 346                            n                  n                      n
# 347                            n                  y                      y
#
#     crime duty-free-exports export-administration-act-south-africa
# 0       y                 n                                      y
# 1       y                 n                                      n
# 2       n                 n                                      y
# 3       y                 y                                      y
# 4       y                 y                                      y
# ..    ...               ...                                    ...
# 343     y                 n                                      y
# 344     ?                 y                                      y
# 345     y                 n                                      y
# 346     n                 n                                      y
# 347     y                 n                                      y
#
# [348 rows x 16 columns]

# %% [markdown]
# ### 4. Data preprocessing

# %% [markdown]
# When you preprocess your traing data, do not forget that you need to apply the same preprocessing also for your test set. For example: If you decide to delete some columns in your train set, you have to delete the same columns in your test set.

# %% [markdown]
# Possible preprocessing steps (try several and see the influence of your preprocessing on your results)
#  - Replace missing values with any data imputation technique ( for example, the most occurring value in the column), then perform one-hot encoding or label encoding of your data
#  - Consider the missing value to be the third category 'unknown' and then perform one-hot encoding or label encoding
#
# The target value also has to be encoded. This can be done by one-hot encoding or label encoding.

# %%
def preprocess_features(df):
    df = df.copy()
    for col in df.columns:
        # Replace '?' with the most frequent value
        most_frequent = df[col][df[col] != '?'].mode()[0]
        df[col] = df[col].replace('?', most_frequent)
        # Label encode: 'n' -> 0, 'y' -> 1
        df[col] = df[col].map({'n': 0, 'y': 1}).astype(np.float32)
    return df.values

x_train_processed = preprocess_features(x_train)

# %%
# Call the train_test_split function defined previously
x_train, y_train, x_test, y_test = train_test_split(pd_dataset)

# %%
# Encode labels: 'democrat' -> 0, 'republican' -> 1
def encode_labels(labels):
    return labels.map({'democrat': 0, 'republican': 1}).values.astype(np.float32)

y_train_encoded = encode_labels(y_train)

# %% [markdown]
# ### 5. Creating the model

# %% [markdown]
# 1. Create your model using alteast one hidden layer.
#
# *hint: do not create too complex models, this is a very simple task, so it would be enought to use just few neurons in the hidden layers*

# %%
# IMPORTANT: Re-run this cell to re-initialize the model with new weights every time you want to train from scratch.
from tensorflow.keras.layers import Dropout, InputLayer

model = Sequential()
model.add(InputLayer(shape=(16,))) # Explicit InputLayer
model.add(Dense(128, activation='relu')) # Reverted to 128 neurons
model.add(Dropout(0.2)) # Keeping Dropout
model.add(Dense(64, activation='relu')) # Reverted to 64 neurons
model.add(Dense(1, activation='sigmoid')) # Output layer

# %% [markdown]
# 2. Check what *model.summary()* does

# %%
model.summary()
# Out:
# Model: "sequential_27"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_73 (Dense)                │ (None, 128)            │         2,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_74 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_75 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,497 (41.00 KB)
#  Trainable params: 10,497 (41.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# 3. Compile the model, choose a suitable loss function, choose gradient to descend optimizer and specify the learning rate, and choose accuracy as our metric

# %%
# IMPORTANT: Re-run this cell to re-compile the model every time you re-initialize it or change its structure/optimizer.
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0005) # Reduced learning rate
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %% [markdown]
# 4. Train the model. Specify the number of epochs and batch size. Now is the time to create a validation dataset. Set 20% of dataset to be a validation dataset

# %%
# IMPORTANT: Re-run this cell to re-train the model every time you want to start a new training run.
history = model.fit(
    x_train_processed, y_train_encoded,
    epochs=1000, # Increased number of epochs to 1000
    batch_size=32,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - accuracy: 0.8129 - loss: 0.5754 - val_accuracy: 0.8429 - val_loss: 0.5631
# Epoch 2/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8957 - loss: 0.4679 - val_accuracy: 0.8429 - val_loss: 0.4885
# Epoch 3/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8885 - loss: 0.3995 - val_accuracy: 0.8429 - val_loss: 0.4340
# Epoch 4/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8993 - loss: 0.3300 - val_accuracy: 0.8429 - val_loss: 0.3983
# Epoch 5/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9029 - loss: 0.2959 - val_accuracy: 0.8429 - val_loss: 0.3753
# Epoch 6/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9101 - loss: 0.2603 - val_accuracy: 0.8429 - val_loss: 0.3591
# Epoch 7/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9101 - loss: 0.2447 - val_accuracy: 0.8429 - val_loss: 0.3457
# Epoch 8/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9209 - loss: 0.2097 - val_accuracy: 0.8571 - val_loss: 0.3331
# Epoch 9/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.
1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9784 - loss: 0.0538 - val_accuracy: 0.9143 - val_loss: 0.2744
# Epoch 41/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0440 - val_accuracy: 0.9143 - val_loss: 0.2816
# Epoch 42/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0402 - val_accuracy: 0.9143 - val_loss: 0.2835
# Epoch 43/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9856 - loss: 0.0362 - val_accuracy: 0.9143 - val_loss: 0.2888
# Epoch 44/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9820 - loss: 0.0443 - val_accuracy: 0.9143 - val_loss: 0.2951
# Epoch 45/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9820 - loss: 0.0388 - val_accuracy: 0.9143 - val_loss: 0.2947
# Epoch 46/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9820 - loss: 0.0449 - val_accuracy: 0.9143 - val_loss: 0.2851
# Epoch 47/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9856 - loss: 0.0384 - val_accuracy: 0.9143 - val_loss: 0.2861
# Epoch 48/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9784 - loss: 0.0503 - val_accuracy: 0.9143 - val_loss: 0.2915
# Epoch 49/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9820 - loss: 0.0400 - val_accuracy: 0.9143 - val_loss: 0.2993
# Epoch 50/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9784 - loss: 0.0487 - val_accuracy: 0.9143 - val_loss: 0.3021
# Epoch 51/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0440 - val_accuracy: 0.9143 - val_loss: 0.2943
# Epoch 52/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9820 - loss: 0.0493 - val_accuracy: 0.9143 - val_loss: 0.2971
# Epoch 53/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9856 - loss: 0.0383 - val_accuracy: 0.9143 - val_loss: 0.3021
# Epoch 54/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0282 - val_accuracy: 0.9143 - val_loss: 0.3025
# Epoch 55/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9820 - loss: 0.0357 - val_accuracy: 0.9143 - val_loss: 0.3051
# Epoch 56/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9820 - loss: 0.0383 - val_accuracy: 0.9143 - val_loss: 0.3099
# Epoch 57/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9892 - loss: 0.0311 - val_accuracy: 0.9143 - val_loss: 0.3107
# Epoch 58/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0301 - val_accuracy: 0.9143 - val_loss: 0.3172
# Epoch 59/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9856 - loss: 0.0377 - val_accuracy: 0.9143 - val_loss: 0.3289
# Epoch 60/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0373 - val_accuracy: 0.9143 - val_loss: 0.3231
# Epoch 61/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9820 - loss: 0.0386 - val_accuracy: 0.9143 - val_loss: 0.3174
# Epoch 62/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9820 - loss: 0.0345 - val_accuracy: 0.9143 - val_loss: 0.3220
# Epoch 63/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0386 - val_accuracy: 0.9143 - val_loss: 0.3299
# Epoch 64/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9820 - loss: 0.0303 - val_accuracy: 0.9143 - val_loss: 0.3327
# Epoch 65/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0261 - val_accuracy: 0.9143 - val_loss: 0.3268
# Epoch 66/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0260 - val_accuracy: 0.9143 - val_loss: 0.3253
# Epoch 67/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0317 - val_accuracy: 0.9143 - val_loss: 0.3245
# Epoch 68/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0282 - val_accuracy: 0.9143 - val_loss: 0.3344
# Epoch 69/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0334 - val_accuracy: 0.9143 - val_loss: 0.3362
# Epoch 70/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0258 - val_accuracy: 0.9143 - val_loss: 0.3337
# Epoch 71/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0270 - val_accuracy: 0.9143 - val_loss: 0.3394
# Epoch 72/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0355 - val_accuracy: 0.9143 - val_loss: 0.3416
# Epoch 73/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0257 - val_accuracy: 0.9143 - val_loss: 0.3375
# Epoch 74/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0336 - val_accuracy: 0.9143 - val_loss: 0.3399
# Epoch 75/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0311 - val_accuracy: 0.9143 - val_loss: 0.3369
# Epoch 76/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0286 - val_accuracy: 0.9143 - val_loss: 0.3422
# Epoch 77/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9856 - loss: 0.0313 - val_accuracy: 0.9143 - val_loss: 0.3468
# Epoch 78/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9856 - loss: 0.0293 - val_accuracy: 0.9143 - val_loss: 0.3477
# Epoch 79/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0220 - val_accuracy: 0.9143 - val_loss: 0.3523
# Epoch 80/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0299 - val_accuracy: 0.9143 - val_loss: 0.3586
# Epoch 81/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0236 - val_accuracy: 0.9143 - val_loss: 0.3544
# Epoch 82/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0220 - val_accuracy: 0.9143 - val_loss: 0.3545
# Epoch 83/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9856 - loss: 0.0306 - val_accuracy: 0.9143 - val_loss: 0.3567
# Epoch 84/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0344 - val_accuracy: 0.9143 - val_loss: 0.3613
# Epoch 85/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9856 - loss: 0.0300 - val_accuracy: 0.9143 - val_loss: 0.3565
# Epoch 86/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9964 - loss: 0.0180 - val_accuracy: 0.9143 - val_loss: 0.3644
# Epoch 87/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0218 - val_accuracy: 0.9143 - val_loss: 0.3729
# Epoch 88/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0279 - val_accuracy: 0.9143 - val_loss: 0.3797
# Epoch 89/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9856 - loss: 0.0224 - val_accuracy: 0.9143 - val_loss: 0.3731
# Epoch 90/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0187 - val_accuracy: 0.9143 - val_loss: 0.3748
# Epoch 91/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0186 - val_accuracy: 0.9143 - val_loss: 0.3747
# Epoch 92/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9856 - loss: 0.0280 - val_accuracy: 0.9143 - val_loss: 0.3778
# Epoch 93/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0167 - val_accuracy: 0.9143 - val_loss: 0.3758
# Epoch 94/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9928 - loss: 0.0215 - val_accuracy: 0.9143 - val_loss: 0.3737
# Epoch 95/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0170 - val_accuracy: 0.9143 - val_loss: 0.3754
# Epoch 96/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0211 - val_accuracy: 0.9143 - val_loss: 0.3825
# Epoch 97/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0203 - val_accuracy: 0.9143 - val_loss: 0.3796
# Epoch 98/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9928 - loss: 0.0173 - val_accuracy: 0.9143 - val_loss: 0.3827
# Epoch 99/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0178 - val_accuracy: 0.9143 - val_loss: 0.3894
# Epoch 100/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0203 - val_accuracy: 0.9143 - val_loss: 0.3892
# Epoch 101/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0256 - val_accuracy: 0.9143 - val_loss: 0.3914
# Epoch 102/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0239 - val_accuracy: 0.9143 - val_loss: 0.3924
# Epoch 103/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9892 - loss: 0.0227 - val_accuracy: 0.9143 - val_loss: 0.3915
# Epoch 104/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0238 - val_accuracy: 0.9143 - val_loss: 0.3943
# Epoch 105/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0216 - val_accuracy: 0.9143 - val_loss: 0.4012
# Epoch 106/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0278 - val_accuracy: 0.9143 - val_loss: 0.4027
# Epoch 107/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0162 - val_accuracy: 0.9143 - val_loss: 0.4024
# Epoch 108/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9820 - loss: 0.0272 - val_accuracy: 0.9143 - val_loss: 0.4024
# Epoch 109/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0299 - val_accuracy: 0.9143 - val_loss: 0.3939
# Epoch 110/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9856 - loss: 0.0251 - val_accuracy: 0.9143 - val_loss: 0.3850
# Epoch 111/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.
1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9856 - loss: 0.0241 - val_accuracy: 0.9143 - val_loss: 0.4897
# Epoch 146/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0187 - val_accuracy: 0.9143 - val_loss: 0.4779
# Epoch 147/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0181 - val_accuracy: 0.9143 - val_loss: 0.4727
# Epoch 148/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9928 - loss: 0.0133 - val_accuracy: 0.9143 - val_loss: 0.4687
# Epoch 149/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0194 - val_accuracy: 0.9143 - val_loss: 0.4676
# Epoch 150/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0151 - val_accuracy: 0.9143 - val_loss: 0.4635
# Epoch 151/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0162 - val_accuracy: 0.9143 - val_loss: 0.4649
# Epoch 152/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0174 - val_accuracy: 0.9143 - val_loss: 0.4636
# Epoch 153/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0122 - val_accuracy: 0.9143 - val_loss: 0.4655
# Epoch 154/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9928 - loss: 0.0146 - val_accuracy: 0.9143 - val_loss: 0.4783
# Epoch 155/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0136 - val_accuracy: 0.9143 - val_loss: 0.4882
# Epoch 156/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0149 - val_accuracy: 0.9143 - val_loss: 0.4795
# Epoch 157/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0141 - val_accuracy: 0.9143 - val_loss: 0.4794
# Epoch 158/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0110 - val_accuracy: 0.9143 - val_loss: 0.4839
# Epoch 159/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0175 - val_accuracy: 0.9143 - val_loss: 0.4846
# Epoch 160/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0212 - val_accuracy: 0.9143 - val_loss: 0.4882
# Epoch 161/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0125 - val_accuracy: 0.9143 - val_loss: 0.4954
# Epoch 162/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0133 - val_accuracy: 0.9143 - val_loss: 0.5024
# Epoch 163/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9892 - loss: 0.0154 - val_accuracy: 0.9143 - val_loss: 0.5009
# Epoch 164/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0110 - val_accuracy: 0.9143 - val_loss: 0.4949
# Epoch 165/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0184 - val_accuracy: 0.9143 - val_loss: 0.4879
# Epoch 166/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0155 - val_accuracy: 0.9143 - val_loss: 0.4760
# Epoch 167/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0220 - val_accuracy: 0.9143 - val_loss: 0.4738
# Epoch 168/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0134 - val_accuracy: 0.9143 - val_loss: 0.4758
# Epoch 169/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0131 - val_accuracy: 0.9143 - val_loss: 0.4803
# Epoch 170/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0118 - val_accuracy: 0.9143 - val_loss: 0.4868
# Epoch 171/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0143 - val_accuracy: 0.9143 - val_loss: 0.4910
# Epoch 172/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9928 - loss: 0.0156 - val_accuracy: 0.9143 - val_loss: 0.4974
# Epoch 173/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0196 - val_accuracy: 0.9143 - val_loss: 0.5094
# Epoch 174/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0172 - val_accuracy: 0.9143 - val_loss: 0.5231
# Epoch 175/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0082 - val_accuracy: 0.9143 - val_loss: 0.5234
# Epoch 176/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0145 - val_accuracy: 0.9143 - val_loss: 0.5228
# Epoch 177/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0172 - val_accuracy: 0.9143 - val_loss: 0.5161
# Epoch 178/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0160 - val_accuracy: 0.9143 - val_loss: 0.5102
# Epoch 179/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0158 - val_accuracy: 0.9143 - val_loss: 0.5065
# Epoch 180/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0139 - val_accuracy: 0.9143 - val_loss: 0.5089
# Epoch 181/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9928 - loss: 0.0147 - val_accuracy: 0.9143 - val_loss: 0.5122
# Epoch 182/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0107 - val_accuracy: 0.9143 - val_loss: 0.5167
# Epoch 183/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0143 - val_accuracy: 0.9143 - val_loss: 0.5179
# Epoch 184/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0148 - val_accuracy: 0.9143 - val_loss: 0.5158
# Epoch 185/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0122 - val_accuracy: 0.9143 - val_loss: 0.5174
# Epoch 186/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0141 - val_accuracy: 0.9143 - val_loss: 0.5215
# Epoch 187/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0128 - val_accuracy: 0.9143 - val_loss: 0.5287
# Epoch 188/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0164 - val_accuracy: 0.9143 - val_loss: 0.5337
# Epoch 189/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0141 - val_accuracy: 0.9143 - val_loss: 0.5420
# Epoch 190/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9928 - loss: 0.0136 - val_accuracy: 0.9143 - val_loss: 0.5452
# Epoch 191/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0117 - val_accuracy: 0.9143 - val_loss: 0.5426
# Epoch 192/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0207 - val_accuracy: 0.9143 - val_loss: 0.5361
# Epoch 193/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0145 - val_accuracy: 0.9143 - val_loss: 0.5376
# Epoch 194/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0141 - val_accuracy: 0.9143 - val_loss: 0.5388
# Epoch 195/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0107 - val_accuracy: 0.9143 - val_loss: 0.5398
# Epoch 196/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0098 - val_accuracy: 0.9143 - val_loss: 0.5410
# Epoch 197/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0140 - val_accuracy: 0.9143 - val_loss: 0.5397
# Epoch 198/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0107 - val_accuracy: 0.9143 - val_loss: 0.5419
# Epoch 199/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9964 - loss: 0.0117 - val_accuracy: 0.9143 - val_loss: 0.5367
# Epoch 200/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0181 - val_accuracy: 0.9143 - val_loss: 0.5239
# Epoch 201/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0247 - val_accuracy: 0.9143 - val_loss: 0.5226
# Epoch 202/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0133 - val_accuracy: 0.9143 - val_loss: 0.5268
# Epoch 203/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0180 - val_accuracy: 0.9143 - val_loss: 0.5336
# Epoch 204/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0096 - val_accuracy: 0.9143 - val_loss: 0.5384
# Epoch 205/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0146 - val_accuracy: 0.9143 - val_loss: 0.5394
# Epoch 206/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0216 - val_accuracy: 0.9143 - val_loss: 0.5454
# Epoch 207/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0155 - val_accuracy: 0.9143 - val_loss: 0.5499
# Epoch 208/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9892 - loss: 0.0138 - val_accuracy: 0.9143 - val_loss: 0.5446
# Epoch 209/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0179 - val_accuracy: 0.9143 - val_loss: 0.5370
# Epoch 210/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0168 - val_accuracy: 0.9143 - val_loss: 0.5373
# Epoch 211/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.9143 - val_loss: 0.5400
# Epoch 212/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0161 - val_accuracy: 0.9143 - val_loss: 0.5407
# Epoch 213/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0106 - val_accuracy: 0.9143 - val_loss: 0.5441
# Epoch 214/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0154 - val_accuracy: 0.9143 - val_loss: 0.5458
# Epoch 215/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0102 - val_accuracy: 0.9143 - val_loss: 0.5469
# Epoch 216/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0168 - val_accuracy: 0.9143 - val_loss: 0.5475
# Epoch 217/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9892 - loss: 0.0140 - val_accuracy: 0.9143 - val_loss: 0.5549
# Epoch 218/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0082 - val_accuracy: 0.9143 - val_loss: 0.5572
# Epoch 219/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0108 - val_accuracy: 0.9143 - val_loss: 0.5568
# Epoch 220/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9928 - loss: 0.0105 - val_accuracy: 0.9143 - val_loss: 0.5573
# Epoch 221/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9928 - loss: 0.0150 - val_accuracy: 0.9143 - val_loss: 0.5596
# Epoch 222/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.
1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0139 - val_accuracy: 0.9143 - val_loss: 0.5846
# Epoch 256/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0113 - val_accuracy: 0.9143 - val_loss: 0.5904
# Epoch 257/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0095 - val_accuracy: 0.9143 - val_loss: 0.5883
# Epoch 258/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0108 - val_accuracy: 0.9143 - val_loss: 0.5848
# Epoch 259/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0089 - val_accuracy: 0.9143 - val_loss: 0.5859
# Epoch 260/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.9143 - val_loss: 0.5828
# Epoch 261/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.9143 - val_loss: 0.5828
# Epoch 262/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0121 - val_accuracy: 0.9143 - val_loss: 0.5859
# Epoch 263/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0103 - val_accuracy: 0.9143 - val_loss: 0.5910
# Epoch 264/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0096 - val_accuracy: 0.9143 - val_loss: 0.5918
# Epoch 265/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0140 - val_accuracy: 0.9143 - val_loss: 0.5857
# Epoch 266/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0130 - val_accuracy: 0.9143 - val_loss: 0.5825
# Epoch 267/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0191 - val_accuracy: 0.9143 - val_loss: 0.5822
# Epoch 268/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0121 - val_accuracy: 0.9143 - val_loss: 0.5910
# Epoch 269/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9856 - loss: 0.0210 - val_accuracy: 0.9143 - val_loss: 0.5925
# Epoch 270/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9856 - loss: 0.0173 - val_accuracy: 0.9143 - val_loss: 0.5999
# Epoch 271/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0130 - val_accuracy: 0.9143 - val_loss: 0.6040
# Epoch 272/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9856 - loss: 0.0186 - val_accuracy: 0.9143 - val_loss: 0.6043
# Epoch 273/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0138 - val_accuracy: 0.9143 - val_loss: 0.5999
# Epoch 274/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0171 - val_accuracy: 0.9143 - val_loss: 0.6063
# Epoch 275/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0150 - val_accuracy: 0.9143 - val_loss: 0.6053
# Epoch 276/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0107 - val_accuracy: 0.9143 - val_loss: 0.6008
# Epoch 277/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0136 - val_accuracy: 0.9143 - val_loss: 0.5984
# Epoch 278/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9928 - loss: 0.0158 - val_accuracy: 0.9143 - val_loss: 0.6029
# Epoch 279/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0110 - val_accuracy: 0.9143 - val_loss: 0.6017
# Epoch 280/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0153 - val_accuracy: 0.9143 - val_loss: 0.5999
# Epoch 281/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0099 - val_accuracy: 0.9143 - val_loss: 0.6007
# Epoch 282/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0129 - val_accuracy: 0.9143 - val_loss: 0.6023
# Epoch 283/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0143 - val_accuracy: 0.9143 - val_loss: 0.6032
# Epoch 284/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0114 - val_accuracy: 0.9143 - val_loss: 0.6087
# Epoch 285/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0144 - val_accuracy: 0.9143 - val_loss: 0.6111
# Epoch 286/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0079 - val_accuracy: 0.9143 - val_loss: 0.6143
# Epoch 287/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9892 - loss: 0.0167 - val_accuracy: 0.9143 - val_loss: 0.6131
# Epoch 288/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0128 - val_accuracy: 0.9143 - val_loss: 0.6124
# Epoch 289/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0139 - val_accuracy: 0.9143 - val_loss: 0.6090
# Epoch 290/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0117 - val_accuracy: 0.9143 - val_loss: 0.6190
# Epoch 291/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0157 - val_accuracy: 0.9143 - val_loss: 0.6096
# Epoch 292/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0105 - val_accuracy: 0.9143 - val_loss: 0.5847
# Epoch 293/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0151 - val_accuracy: 0.9143 - val_loss: 0.5753
# Epoch 294/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0153 - val_accuracy: 0.9143 - val_loss: 0.5894
# Epoch 295/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0209 - val_accuracy: 0.9143 - val_loss: 0.5859
# Epoch 296/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9892 - loss: 0.0132 - val_accuracy: 0.9143 - val_loss: 0.5762
# Epoch 297/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0146 - val_accuracy: 0.9143 - val_loss: 0.5763
# Epoch 298/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0079 - val_accuracy: 0.9143 - val_loss: 0.5832
# Epoch 299/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9856 - loss: 0.0179 - val_accuracy: 0.9143 - val_loss: 0.5922
# Epoch 300/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9964 - loss: 0.0088 - val_accuracy: 0.9143 - val_loss: 0.5948
# Epoch 301/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0141 - val_accuracy: 0.9143 - val_loss: 0.6012
# Epoch 302/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0085 - val_accuracy: 0.9143 - val_loss: 0.5995
# Epoch 303/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9892 - loss: 0.0169 - val_accuracy: 0.9143 - val_loss: 0.6016
# Epoch 304/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0154 - val_accuracy: 0.9143 - val_loss: 0.6078
# Epoch 305/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0147 - val_accuracy: 0.9143 - val_loss: 0.6097
# Epoch 306/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0124 - val_accuracy: 0.9143 - val_loss: 0.6140
# Epoch 307/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0121 - val_accuracy: 0.9143 - val_loss: 0.6194
# Epoch 308/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 0.9143 - val_loss: 0.6230
# Epoch 309/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0114 - val_accuracy: 0.9143 - val_loss: 0.6226
# Epoch 310/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0121 - val_accuracy: 0.9143 - val_loss: 0.6175
# Epoch 311/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0142 - val_accuracy: 0.9143 - val_loss: 0.6136
# Epoch 312/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0178 - val_accuracy: 0.9143 - val_loss: 0.6127
# Epoch 313/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9892 - loss: 0.0150 - val_accuracy: 0.9143 - val_loss: 0.6076
# Epoch 314/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0082 - val_accuracy: 0.9143 - val_loss: 0.6045
# Epoch 315/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0115 - val_accuracy: 0.9143 - val_loss: 0.6064
# Epoch 316/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0117 - val_accuracy: 0.9143 - val_loss: 0.6116
# Epoch 317/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0092 - val_accuracy: 0.9143 - val_loss: 0.6132
# Epoch 318/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0106 - val_accuracy: 0.9143 - val_loss: 0.6125
# Epoch 319/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0161 - val_accuracy: 0.9143 - val_loss: 0.6119
# Epoch 320/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0127 - val_accuracy: 0.9143 - val_loss: 0.6111
# Epoch 321/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0128 - val_accuracy: 0.9143 - val_loss: 0.6146
# Epoch 322/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9964 - loss: 0.0086 - val_accuracy: 0.9143 - val_loss: 0.6161
# Epoch 323/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0101 - val_accuracy: 0.9143 - val_loss: 0.6149
# Epoch 324/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9892 - loss: 0.0125 - val_accuracy: 0.9143 - val_loss: 0.6136
# Epoch 325/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0104 - val_accuracy: 0.9143 - val_loss: 0.6163
# Epoch 326/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0132 - val_accuracy: 0.9143 - val_loss: 0.6197
# Epoch 327/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0098 - val_accuracy: 0.9143 - val_loss: 0.6223
# Epoch 328/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9964 - loss: 0.0091 - val_accuracy: 0.9143 - val_loss: 0.6293
# Epoch 329/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9964 - loss: 0.0105 - val_accuracy: 0.9143 - val_loss: 0.6338
# Epoch 330/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9856 - loss: 0.0149 - val_accuracy: 0.9143 - val_loss: 0.6310
# Epoch 331/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9928 - loss: 0.0114 - val_accuracy: 0.9143 - val_loss: 0.6286
# Epoch 332/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9964 - loss: 0.0096 - val_accuracy: 0.9143 - val_loss: 0.6293
# Epoch 333/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9964 - loss: 0.0104 - val_accuracy: 0.9143 - val_loss: 0.6314
# Epoch 334/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9964 - loss: 0.0120 - val_accuracy: 0.9143 - val_loss: 0.6353
# Epoch 335/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9928 - loss: 0.0093 - val_accuracy: 0.9143 - val_loss: 0.6228
# Epoch 336/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9964 - loss: 0.0107 - val_accuracy: 0.9143 - val_loss: 0.6163
# Epoch 337/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9892 - loss: 0.0123 - val_accuracy: 0.9143 - val_loss: 0.6136
# Epoch 338/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9928 - loss: 0.0111 - val_accuracy: 0.9143 - val_loss: 0.6177
# Epoch 339/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9928 - loss: 0.0100 - val_accuracy: 0.9143 - val_loss: 0.6250
# Epoch 340/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9892 - loss: 0.0161 - val_accuracy: 0.9143 - val_loss: 0.6099
# Epoch 341/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.9143 - val_loss: 0.6014
# Epoch 342/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9892 - loss: 0.0153 - val_accuracy: 0.9143 - val_loss: 0.6054
# Epoch 343/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9892 - loss: 0.0174 - val_accuracy: 0.9143 - val_loss: 0.6070
# Epoch 344/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9892 - loss: 0.0140 - val_accuracy: 0.9143 - val_loss: 0.6133
# Epoch 345/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9928 - loss: 0.0130 - val_accuracy: 0.9143 - val_loss: 0.6174
# Epoch 346/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9964 - loss: 0.0108 - val_accuracy: 0.9143 - val_loss: 0.6223
# Epoch 347/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9856 - loss: 0.0137 - val_accuracy: 0.9143 - val_loss: 0.6264
# Epoch 348/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0086 - val_accuracy: 0.9143 - val_loss: 0.6355
# Epoch 349/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0107 - val_accuracy: 0.9143 - val_loss: 0.6350
# Epoch 350/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0118 - val_accuracy: 0.9143 - val_loss: 0.6318
# Epoch 351/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0135 - val_accuracy: 0.9143 - val_loss: 0.6385
# Epoch 352/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0078 - val_accuracy: 0.9143 - val_loss: 0.6429
# Epoch 353/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9928 - loss: 0.0132 - val_accuracy: 0.9143 - val_loss: 0.6427
# Epoch 354/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0095 - val_accuracy: 0.9143 - val_loss: 0.6466
# Epoch 355/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0111 - val_accuracy: 0.9143 - val_loss: 0.6506
# Epoch 356/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0094 - val_accuracy: 0.9143 - val_loss: 0.6522
# Epoch 357/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0148 - val_accuracy: 0.9143 - val_loss: 0.6489
# Epoch 358/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0090 - val_accuracy: 0.9143 - val_loss: 0.6474
# Epoch 359/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0089 - val_accuracy: 0.9143 - val_loss: 0.6503
# Epoch 360/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0112 - val_accuracy: 0.9143 - val_loss: 0.6537
# Epoch 361/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0096 - val_accuracy: 0.9143 - val_loss: 0.6542
# Epoch 362/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0107 - val_accuracy: 0.9143 - val_loss: 0.6577
# Epoch 363/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9856 - loss: 0.0167 - val_accuracy: 0.9143 - val_loss: 0.6573
# Epoch 364/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0113 - val_accuracy: 0.9143 - val_loss: 0.6558
# Epoch 365/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0117 - val_accuracy: 0.9143 - val_loss: 0.6572
# Epoch 366/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0171 - val_accuracy: 0.9143 - val_loss: 0.6562
# Epoch 367/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0074 - val_accuracy: 0.9143 - val_loss: 0.6567
# Epoch 368/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0124 - val_accuracy: 0.9143 - val_loss: 0.6579
# Epoch 369/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9856 - loss: 0.0148 - val_accuracy: 0.9143 - val_loss: 0.6595
# Epoch 370/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9964 - loss: 0.0095 - val_accuracy: 0.9143 - val_loss: 0.6645
# Epoch 371/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0135 - val_accuracy: 0.9143 - val_loss: 0.6735
# Epoch 372/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9964 - loss: 0.0114 - val_accuracy: 0.9143 - val_loss: 0.6889
# Epoch 373/1000
# ...
# Epoch 877/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9892 - loss: 0.0106 - val_accuracy: 0.9143 - val_loss: 0.9492
# Epoch 878/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0104 - val_accuracy: 0.9143 - val_loss: 0.9470
# Epoch 879/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0114 - val_accuracy: 0.9143 - val_loss: 0.9467
# Epoch 880/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9892 - loss: 0.0117 - val_accuracy: 0.9143 - val_loss: 0.9459
# Epoch 881/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9892 - loss: 0.0111 - val_accuracy: 0.9143 - val_loss: 0.9480
# Epoch 882/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9928 - loss: 0.0096 - val_accuracy: 0.9143 - val_loss: 0.9472
# Epoch 883/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0098 - val_accuracy: 0.9143 - val_loss: 0.9477
# Epoch 884/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0118 - val_accuracy: 0.9143 - val_loss: 0.9479
# Epoch 885/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0110 - val_accuracy: 0.9143 - val_loss: 0.9477
# Epoch 886/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9892 - loss: 0.0105 - val_accuracy: 0.9143 - val_loss: 0.9464
# Epoch 887/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9856 - loss: 0.0118 - val_accuracy: 0.9143 - val_loss: 0.9444
# Epoch 888/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9928 - loss: 0.0103 - val_accuracy: 0.9143 - val_loss: 0.9406
# Epoch 889/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0093 - val_accuracy: 0.9143 - val_loss: 0.9381
# Epoch 890/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9820 - loss: 0.0146 - val_accuracy: 0.9143 - val_loss: 0.8905
# Epoch 891/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0104 - val_accuracy: 0.9143 - val_loss: 0.8563
# Epoch 892/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0103 - val_accuracy: 0.9143 - val_loss: 0.8621
# Epoch 893/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0104 - val_accuracy: 0.9143 - val_loss: 0.8726
# Epoch 894/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9928 - loss: 0.0118 - val_accuracy: 0.9143 - val_loss: 0.8768
# Epoch 895/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0113 - val_accuracy: 0.9143 - val_loss: 0.8832
# Epoch 896/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0091 - val_accuracy: 0.9143 - val_loss: 0.8962
# Epoch 897/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0093 - val_accuracy: 0.9143 - val_loss: 0.9044
# Epoch 898/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9892 - loss: 0.0104 - val_accuracy: 0.9143 - val_loss: 0.9074
# Epoch 899/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0116 - val_accuracy: 0.9143 - val_loss: 0.9056
# Epoch 900/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9928 - loss: 0.0100 - val_accuracy: 0.9143 - val_loss: 0.9066
# Epoch 901/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9856 - loss: 0.0113 - val_accuracy: 0.9143 - val_loss: 0.9091
# Epoch 902/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0109 - val_accuracy: 0.9143 - val_loss: 0.9118
# Epoch 903/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9856 - loss: 0.0117 - val_accuracy: 0.9143 - val_loss: 0.9386
# Epoch 904/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9964 - loss: 0.0098 - val_accuracy: 0.9143 - val_loss: 0.9582
# Epoch 905/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.
1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9928 - loss: 0.0097 - val_accuracy: 0.9143 - val_loss: 0.9757
# Epoch 938/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0112 - val_accuracy: 0.9143 - val_loss: 0.9866
# Epoch 939/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9964 - loss: 0.0103 - val_accuracy: 0.9143 - val_loss: 0.9828
# Epoch 940/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0098 - val_accuracy: 0.9143 - val_loss: 0.9800
# Epoch 941/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9928 - loss: 0.0091 - val_accuracy: 0.9143 - val_loss: 0.9795
# Epoch 942/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0093 - val_accuracy: 0.9143 - val_loss: 0.9818
# Epoch 943/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0097 - val_accuracy: 0.9143 - val_loss: 0.9827
# Epoch 944/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9892 - loss: 0.0096 - val_accuracy: 0.9143 - val_loss: 0.9898
# Epoch 945/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9856 - loss: 0.0133 - val_accuracy: 0.9143 - val_loss: 0.9865
# Epoch 946/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0116 - val_accuracy: 0.9143 - val_loss: 0.9799
# Epoch 947/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0100 - val_accuracy: 0.9143 - val_loss: 0.9796
# Epoch 948/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0082 - val_accuracy: 0.9143 - val_loss: 0.9820
# Epoch 949/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9928 - loss: 0.0105 - val_accuracy: 0.9143 - val_loss: 0.9849
# Epoch 950/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0089 - val_accuracy: 0.9143 - val_loss: 0.9889
# Epoch 951/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0113 - val_accuracy: 0.9143 - val_loss: 0.9928
# Epoch 952/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9928 - loss: 0.0103 - val_accuracy: 0.9143 - val_loss: 0.9910
# Epoch 953/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0101 - val_accuracy: 0.9143 - val_loss: 0.9815
# Epoch 954/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0080 - val_accuracy: 0.9143 - val_loss: 0.9806
# Epoch 955/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0102 - val_accuracy: 0.9143 - val_loss: 0.9781
# Epoch 956/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0152 - val_accuracy: 0.9143 - val_loss: 0.9740
# Epoch 957/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9928 - loss: 0.0093 - val_accuracy: 0.9143 - val_loss: 0.9723
# Epoch 958/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0111 - val_accuracy: 0.9143 - val_loss: 0.9708
# Epoch 959/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0087 - val_accuracy: 0.9143 - val_loss: 0.9700
# Epoch 960/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9892 - loss: 0.0132 - val_accuracy: 0.9143 - val_loss: 0.9652
# Epoch 961/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9892 - loss: 0.0134 - val_accuracy: 0.9143 - val_loss: 0.9588
# Epoch 962/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9928 - loss: 0.0115 - val_accuracy: 0.9143 - val_loss: 0.9530
# Epoch 963/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9856 - loss: 0.0123 - val_accuracy: 0.9143 - val_loss: 0.9583
# Epoch 964/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9964 - loss: 0.0083 - val_accuracy: 0.9143 - val_loss: 0.9622
# Epoch 965/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9928 - loss: 0.0110 - val_accuracy: 0.9143 - val_loss: 0.9668
# Epoch 966/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9928 - loss: 0.0093 - val_accuracy: 0.9143 - val_loss: 0.9881
# Epoch 967/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0088 - val_accuracy: 0.9143 - val_loss: 0.9975
# Epoch 968/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0091 - val_accuracy: 0.9143 - val_loss: 1.0020
# Epoch 969/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0123 - val_accuracy: 0.9143 - val_loss: 0.9734
# Epoch 970/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0121 - val_accuracy: 0.9143 - val_loss: 0.9761
# Epoch 971/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0110 - val_accuracy: 0.9143 - val_loss: 0.9858
# Epoch 972/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9856 - loss: 0.0138 - val_accuracy: 0.9143 - val_loss: 0.9891
# Epoch 973/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9964 - loss: 0.0096 - val_accuracy: 0.9143 - val_loss: 0.9918
# Epoch 974/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9928 - loss: 0.0105 - val_accuracy: 0.9143 - val_loss: 0.9936
# Epoch 975/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0105 - val_accuracy: 0.9143 - val_loss: 0.9908
# Epoch 976/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9928 - loss: 0.0093 - val_accuracy: 0.9143 - val_loss: 0.9925
# Epoch 977/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 0.9143 - val_loss: 0.9917
# Epoch 978/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0108 - val_accuracy: 0.9143 - val_loss: 0.9910
# Epoch 979/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0096 - val_accuracy: 0.9143 - val_loss: 0.9901
# Epoch 980/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0109 - val_accuracy: 0.9143 - val_loss: 0.9900
# Epoch 981/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9928 - loss: 0.0107 - val_accuracy: 0.9143 - val_loss: 0.9903
# Epoch 982/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9928 - loss: 0.0097 - val_accuracy: 0.9143 - val_loss: 0.9900
# Epoch 983/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0096 - val_accuracy: 0.9143 - val_loss: 0.9930
# Epoch 984/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0109 - val_accuracy: 0.9143 - val_loss: 1.0114
# Epoch 985/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0092 - val_accuracy: 0.9286 - val_loss: 1.0217
# Epoch 986/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.9143 - val_loss: 0.9916
# Epoch 987/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0108 - val_accuracy: 0.9143 - val_loss: 0.9733
# Epoch 988/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0122 - val_accuracy: 0.9143 - val_loss: 0.9641
# Epoch 989/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9928 - loss: 0.0104 - val_accuracy: 0.9143 - val_loss: 0.9671
# Epoch 990/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.0103 - val_accuracy: 0.9143 - val_loss: 0.9757
# Epoch 991/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0112 - val_accuracy: 0.9143 - val_loss: 0.9786
# Epoch 992/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9856 - loss: 0.0117 - val_accuracy: 0.9143 - val_loss: 0.9784
# Epoch 993/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0111 - val_accuracy: 0.9143 - val_loss: 0.9790
# Epoch 994/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.9143 - val_loss: 0.9811
# Epoch 995/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0120 - val_accuracy: 0.9143 - val_loss: 0.9813
# Epoch 996/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9964 - loss: 0.0097 - val_accuracy: 0.9143 - val_loss: 0.9833
# Epoch 997/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9928 - loss: 0.0109 - val_accuracy: 0.9143 - val_loss: 0.9946
# Epoch 998/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - loss: 0.0103 - val_accuracy: 0.9143 - val_loss: 0.9948
# Epoch 999/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9928 - loss: 0.0096 - val_accuracy: 0.9143 - val_loss: 0.9937
# Epoch 1000/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.9143 - val_loss: 0.9949

# %% [markdown]
# ### 7. Model Evaluation

# %% [markdown]
# 1. First, apply the same preprocessing you did to train set to test set also

# %%
x_test_processed = preprocess_features(x_test)
y_test_encoded = encode_labels(y_test)

# %% [markdown]
# 2. Evaluate the model, print final accuracy and loss

# %%
loss, accuracy = model.evaluate(x_test_processed, y_test_encoded, verbose=0)
print(f'Test Loss: {loss:.4f}')
print(f'Test Accuracy: {accuracy*100:.2f}%')
# Out:
# Test Loss: 0.3707
# Test Accuracy: 94.25%

# %% [markdown]
# 3. Plot loss and validation loss depending on the training epochs into one graph. In another graph, plot accuracy and validation accuracy

# %%
# Plot Loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss over Epochs')
plt.show()

# Plot Accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy over Epochs')
plt.show()
